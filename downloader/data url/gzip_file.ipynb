# %%
import gzip
import shutil

# %%
origin = '/content/drive/My Drive/Data Science Projects/Kickstarter/downloader/data url/collated.json'
destination = '/content/drive/My Drive/Data Science Projects/Kickstarter/downloader/data url/collated.json.gz'

with open(origin, 'rb') as file_in:
    with gzip.open(destination, 'wb') as file_out:
        shutil.copyfileobj(file_in, file_out)

# %%
# !rm /content/drive/My Drive/Data Science Projects/Kickstarter/downloader/data url/collated.json
# Out:
# rm: cannot remove '/content/drive/My': No such file or directory
# rm: cannot remove 'Drive/Data': No such file or directory
# rm: cannot remove 'Science': No such file or directory
# rm: cannot remove 'Projects/Kickstarter/downloader/data': No such file or directory
# rm: cannot remove 'url/collated.json': No such file or directory
