# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pwd
# Out:
# /content

# %%
# %cd gdrive/My Drive/Data Science Projects/Kickstarter
# Out:
# /content/gdrive/My Drive/Data Science Projects/Kickstarter

# %%
# !ls
# Out:
# clean_data.csv	kickstarter_data_preparation.ipynb  scraper
# downloader	kick_starter_EDA.ipynb		    Untitled0.ipynb

# %%
#!git init
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/Data Science Projects/Kickstarter/.git/

# %%
# !git status

# %%
# !git add .

# %%
# !git commit -m 'First Commit'
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@b516b013ba0b.(none)')

# %%
# !git config --global user.email 'nowakhr@gmail.com'
# !git config --global user.name "HRNowak"

# %%
# !git commit -m 'First Commit'
# Out:
# [master (root-commit) fe23194] First Commit
#  17 files changed, 355500 insertions(+)
#  create mode 100644 Untitled0.ipynb
#  create mode 100644 clean_data.csv
#  create mode 100644 downloader/data url/collated.json.gz
#  create mode 100644 downloader/data url/gzip_file.ipynb
#  create mode 100644 downloader/data url/url_prog.pkl
#  create mode 100644 downloader/file_merger_online using url.ipynb
#  create mode 100644 kick_starter_EDA.ipynb
#  create mode 100644 kickstarter_data_preparation.ipynb
#  create mode 100644 scraper/Scraper1/1 Selenium Multi-Scraper
#  create mode 100644 scraper/Scraper1/projects1.json
#  create mode 100644 scraper/Scraper2/2 Selenium Multi-Scraper
#  create mode 100644 scraper/Scraper2/projects2.json
#  create mode 100644 scraper/Scraper3/3 Selenium Multi-Scraper
#  create mode 100644 scraper/Scraper3/projects3.json
#  create mode 100644 scraper/Scraper4/4 Selenium Multi-Scraper
#  create mode 100644 scraper/Scraper4/projects4.json
# ...

# %%
# !git remote add 'https://github.com/HRNowak/kickstarter.git'
# Out:
# usage: git remote add [<options>] <name> <url>
#
#     -f, --fetch           fetch the remote branches
#     --tags                import all tags and associated objects when fetching
#                           or do not fetch any tag at all (--no-tags)
#     -t, --track <branch>  branch(es) to track
#     -m, --master <branch>
#                           master branch
#     --mirror[=<push|fetch>]
#                           set up remote as a mirror to push to or fetch from

# %%
# !git push origin master
# Out:
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git remote rm origin
# Out:
# fatal: failed to stat '/content/gdrive/My Drive/Data Science Projects/Kickstarter': Transport endpoint is not connected

# %%
# !git remote -v

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/Data Science Projects/Kickstarter

# %%
# !git status
# Out:
# fatal: failed to stat '/content/gdrive/My Drive/Data Science Projects/Kickstarter': Transport endpoint is not connected
